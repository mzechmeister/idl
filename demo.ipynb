# %%
iplot, xlabel='"time t [s]"', ylabel='"signal y"'
iplot, cos(dindgen(10)),' pt 7, cos(x) lc 3'
# Out:
# <html><img src='data:image/png;base64,...'/></html>

# %%
ds9, cos(dindgen(10,10)/10), zoom="to 40 40", cmap='bb', obj='my description', frame=1
ds9show
# Out:
# <html><img src='data:image/png;base64,...'/></html>
